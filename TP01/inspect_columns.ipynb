# %% [markdown]
# # Notebook para Inspeccionar las tablas Originales

# %% [markdown]
# ### Indice
#
# - [Checklist](#Checklist)
#
# - [Columnas de las Tablas](#Columnas-de-todas-las-tablas)
#
# - [GDP](#GDP)
#
# - [GDP Metadata](#GDP-Metadata)
#
# - [Lista Sedes Datos](#Lista-Sedes-Datos)
#
# - [Lista Secciones](#Lista-Secciones)
#
# - [Lista Sedes](#Lista-Sedes)

# %% [markdown]
# ## Checklist
#
# - Item 1 [ ]
# - Item 2 [ ] (completed)
# - Item 3 [ ]

# %%
# !pip install pandas

# %%
import pandas as pd

from os import listdir
from os.path import isfile, join

datos = "/home/fran/Github/Laboratorio_de_datos/TP01/TablasOriginales"

pd.set_option('display.max_columns', None)
# Out:
# /tmp/ipykernel_1042569/350010371.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
gdp = pd.read_csv("/home/fran/Github/Laboratorio_de_datos/TP01/TablasOriginales/API_NY.GDP.PCAP.CD_DS2_en_csv_v2_73.csv")
Country_gdp_metadata = pd.read_csv("/home/fran/Github/Laboratorio_de_datos/TP01/TablasOriginales/Metadata_Country_API_NY.GDP.PCAP.CD_DS2_en_csv_v2_73.csv")
lista_sedes_datos = pd.read_csv("TablasOriginales/lista-sedes-datos.csv")
lista_secciones = pd.read_csv("TablasOriginales/lista-secciones.csv")
lista_sedes = pd.read_csv("TablasOriginales/lista-sedes.csv")

# %% [markdown]
# ## Columnas de todas las tablas

# %%
print("GDP\n",gdp.columns, "\n")
print("Country-GDP-metadata\n",Country_gdp_metadata.columns, "\n")
print("lista-sedes-datos\n",lista_sedes_datos.columns,"\n")
print("lista-secciones\n",lista_secciones.columns, "\n")
print("lista-sedes\n",lista_sedes.columns, "\n")
# Out:
# GDP
#  Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')
#
# Country-GDP-metadata
#  Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')
#
# lista-sedes-datos
#  Index(['sede_id', 'sede_desc_castellano', 'sede_desc_ingles',
# ...

# %% [markdown]
# ## Archivos Errores:
#
#
# Los datos de las sedes estan actualizados hasta 2018 - hay que tener cautela sobre como los interpretamos
#
# - GDP:
#
#     - renombramos al archivo para mayor referencia y legibilidad
#     - para leer la data del csv de los datos de GDP hay que sacrale las priemras 4 filas al archivo porque son solo comentarios
#     - esta mal formateado el csv y al leerlo con pandas crea una columna extra llena de Nans
#     -
#
# - Sedes datos:
#
#     - habia un error en la fila 16 del archivo, con una coma extra donde espera una columna menos y al tener esa coma leia que tenia una de mas
#
# - Secciones:
#
#     -
#
# - Sedes:
#
#     -
#
# - Country-GDP-Metadata:
#
#     - esta mal formateado el csv y al leerlo con pandas crea una columna extra llena de Nans

# %% [markdown]
# ## Formas Normales:
#
# - GDP:
#
#     - 1FN -> pasa (todos sus atributos son atomicos)
#     - 2FN -> pregunutar cunado una columna no depende de ninguna otra
#
# - Sedes datos:
#
#     - 1FN: cae -> "redes sociales" -> no cumple con atomicidad
#
# - Secciones:
#
#     - 1FN: cae -> "correo electronico" -> no cumple con atomicidad
#
# - Sedes:
#
#     - 1FN -> pasa (todos sus atributos son atomicos)
#     - 2FN -> pasa
#
# - Country-GDP-Metadata:
#
#     - 1FN -> pasa (todos sus atributos son atomicos)
#     - 2FN -> pasa

# %% [markdown]
# ## GDP

# %%
gdp
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %%
gdp['Indicator Code'].unique()
gdp['Indicator Name'].unique()
# Out:
# array(['GDP per capita (current US$)'], dtype=object)

# %% [markdown]
# ## GDP Metadata

# %%
Country_gdp_metadata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %% [markdown]
# ## Lista Sedes Datos

# %%
lista_sedes_datos
# Out:
#     sede_id                               sede_desc_castellano  \
# 0     CALEG              Consulado  General  en  Porto  Alegre
# 1     CANTO                         Consulado  en  Antofagasta
# 2     CAREN              Consulado  General  en  Punta  Arenas
# 3     CASUN                   Consulado  General  en  Asunción
# 4     CATLA                    Consulado  General  en  Atlanta
# ..      ...                                                ...
# 159   EURUG                              Embajada  en  Uruguay
# 160   EVENE                            Embajada  en  Venezuela
# 161   EVIET                              Embajada  en  Vietnam
# 162   OCCAT  Oficina  Comercial  y  Cultural  Argentina  en...
# 163   REPAL  Oficina  de  Representación  en  el  Estado  d...
#
#                                       sede_desc_ingles  \
# 0                Consulate  General  in  PORTO  ALEGRE
# 1                           Consulate  in  ANTOFAGASTA
# ...

# %% [markdown]
# GQM
#
# relevamiento:
# los datos criticos en esta tabla va a ser 'Redes sociales', que lo queremos pasar a una tabla independiente para que este normalizado, el atributo de interes va a ser la Consistencia y la Completitud
#
# Atributo de calidad afectado 'Redes sociales': Completitud, Consistencia,
#
#
# Completitud ->
#
# Vigencia ->

# %% [markdown]
# ## Lista Secciones

# %%
lista_secciones
# Out:
#     sede_id                               sede_desc_castellano  \
# 0     ECHES                                     Administración
# 1     ERUNI                                     Administración
# 2     EHAIT                                     Administración
# 3     EKENY                                     Administración
# 4     ERUNI                                     Administración
# ..      ...                                                ...
# 511   CRIOJ                                   Sección  Turismo
# 512   EMEXI  Secciones  Cooperación, Educación, Turismo  y ...
# 513   EHILE                                Secretaría  Privada
# 514   CNYOR                                            Turismo
# 515   CNYOR                                              Visas
#
#                                       sede_desc_ingles tipo_seccion  \
# 0                              Administrative  Section      Seccion
# 1                                       Administration      Seccion
# ...

# %% [markdown]
# ## Lista Sedes

# %%
lista_sedes
# Out:
#     sede_id                               sede_desc_castellano  \
# 0     CALEG              Consulado  General  en  Porto  Alegre
# 1     CANTO                         Consulado  en  Antofagasta
# 2     CAREN              Consulado  General  en  Punta  Arenas
# 3     CASUN                   Consulado  General  en  Asunción
# 4     CATLA                    Consulado  General  en  Atlanta
# ..      ...                                                ...
# 159   EURUG                              Embajada  en  Uruguay
# 160   EVENE                            Embajada  en  Venezuela
# 161   EVIET                              Embajada  en  Vietnam
# 162   OCCAT  Oficina  Comercial  y  Cultural  Argentina  en...
# 163   REPAL  Oficina  de  Representación  en  el  Estado  d...
#
#                                       sede_desc_ingles pais_iso_2 pais_iso_3  \
# 0                Consulate  General  in  PORTO  ALEGRE         BR        BRA
# ...

# %% [markdown]
# ## Creacion de DataFrames vacios

# %%
atributos_sede = ['id', 'ciudad', 'descripcion']
sede = pd.DataFrame(columns=atributos_sede)

atributos_seccion = ['id_sede', 'seccion']
seccion = pd.DataFrame(columns=atributos_seccion)

atributos_cuenta = ['id_sede', 'url', 'nombre_red']
cuenta = pd.DataFrame(columns=atributos_cuenta)

atributos_pais = ['iso', 'nombre', 'pbi', 'region']
pais = pd.DataFrame(columns=atributos_pais)

dataframes = [sede, seccion, cuenta, pais]

# %%
for df in dataframes:
    print(df, "\n")
# Out:
# Empty DataFrame
# Columns: [id, ciudad, descripcion]
# Index: []
#
# Empty DataFrame
# Columns: [id_sede, seccion]
# Index: []
#
# Empty DataFrame
# Columns: [id_sede, url, nombre_red]
# Index: []
#
# Empty DataFrame
# Columns: [iso, nombre, pbi, region]
# Index: []

# %%
pbi = gdp[['Country Name', 'Country Code', '2022']]

#pbi.columns = ['Pais', 'iso', 'PBI']

pbi
# Out:
#                     Country Name Country Code          2022
# 0                          Aruba          ABW  33300.838819
# 1    Africa Eastern and Southern          AFE   1644.062829
# 2                    Afghanistan          AFG           NaN
# 3     Africa Western and Central          AFW   1785.312219
# 4                         Angola          AGO   3000.444231
# ..                           ...          ...           ...
# 261                       Kosovo          XKX   5340.268798
# 262                  Yemen, Rep.          YEM    650.272218
# 263                 South Africa          ZAF   6766.481254
# 264                       Zambia          ZMB   1456.901570
# 265                     Zimbabwe          ZWE   1676.821489
#
# [266 rows x 3 columns]

# %%
Country_gdp_metadata = Country_gdp_metadata[['Country Code', 'Region']]
pbi_df = pbi.merge(Country_gdp_metadata, on='Country Code', how='left')

pbi_df.columns = ['Pais', 'iso', 'PBI', 'Region']

pbi_df
# Out:
#                             Pais  iso           PBI  \
# 0                          Aruba  ABW  33300.838819
# 1    Africa Eastern and Southern  AFE   1644.062829
# 2                    Afghanistan  AFG           NaN
# 3     Africa Western and Central  AFW   1785.312219
# 4                         Angola  AGO   3000.444231
# ..                           ...  ...           ...
# 261                       Kosovo  XKX   5340.268798
# 262                  Yemen, Rep.  YEM    650.272218
# 263                 South Africa  ZAF   6766.481254
# 264                       Zambia  ZMB   1456.901570
# 265                     Zimbabwe  ZWE   1676.821489
#
#                          Region
# 0     Latin America & Caribbean
# 1                           NaN
# 2                    South Asia
# 3                           NaN
# 4            Sub-Saharan Africa
# ..                          ...
# 261       Europe & Central Asia
# 262  Middle East & North Africa
# 263          Sub-Saharan Africa
# ...

# %%
lista_sedes[['sede_id', '']]

# %% [markdown]
# ## Procesamiento

# %% [markdown]
# ## Causas de problemas en Calidad de Datos
#
# ### 1. Problemas asociados a la INSTANCIA
#
# -
#
# -
#
# -
#
# ### 2. Problemas asociados al MODELO
#
# -
#
# -
#
#
# ### 3. Problemas asociados a los PROCESOS
#
# - Distintas personas cargan la misma informacion haciendo distintas asunciones
#
# - Se carga con una asuncion y se usa con otras
#
# - Modificaciones manuales por procesos
#
# - Gente que hace modificaciones pero no deberia estar autorizada para hacerlas
#
# ### 4. Problemas asociados a ERRORES DE SOFTWARE
#
# - Datos obligatorios que no se asumen como tales y por lo tanto no se cargan
#
# - Interfaces poco amigables

# %% [markdown]
# ## Atributos de Calidad
#
# 1. Completitud
# - Estan presentes todos los valores para representar la realidad
# - Estan presentes todas las instancias existentes en el mundo real
#
# 2. Relevancia
# - Los datos son relevantes para representar la realidad
#
# 3. Vigencia
# - Los datos se mantinen actualizados con la frecuencia adecuada
#
# 4. Disponibilidad
# - Los datos estan accesibles
#
# 5. Confiabilidad
# - Se puede considerar que los datos representan informacion veridica
#
# 6. Consistencia
# - No hay contradicciones entre distintos datos almacenados
#
# 7. Correccion
# - Los datos representan la situacion real
#
# 8. Seguridad/Privacidad
# - Los datos cumplen con los requerimientos de privacidad adecuados de acuerdo a la reglamentacion nacional-internacional / criterios eticos
#
# - Los datos son solo accesibles por los usuarios autorizados

# %% [markdown]
# ## GQM
# ### Goal Cuestion metric
#
#
# Metodologia:
#  1. Hacer relevamiento
#  2. Elaborar metricas de calidad
#  3. Recolectar valores de dichas metricas
#
#  nos permite cuantificar la calidad de los datos
#
# ## 1. Hacer Relevamiento
#
# ### Objetivo: Determinar
#
#  - Datos criticos
#  - Ciclo de vida del dato
#  - Atributos de interes
#
#
# ### Tareas a relizar:
#
# - Identifiacr stakeholders
# - conseguir el compromiso por parte del cliente - la organizacion
# - Leer documentacion sobre los sistemas, sobre el negocio
# - Hacer cuestionarios tendiednteas a determinar cuales son los datos criticos
# - Llevar adelante los cuestionarios
#
# ## 2. Elavorar metricas de calidad
#
#
# ## 3. Recolectar valores de las metricas

# %%
lista_sedes_datos['redes_sociales'].isna().sum()
# Out:
# 38

# %%
lista_sedes_datos[['redes_sociales']].head(50)
# Out:
#                                        redes_sociales
# 0   https://twitter.com/ArgPortoAlegre  //  https:...
# 1   https://www.facebook.com/Consulado-de-la-Rep%C...
# 2   https://www.facebook.com/profile.php?id=100014...
# 3                          @ArgentinaEnAsuncion  //
# 4                                                 NaN
# 5   facebook.com/ArgEnBarcelona  //  twitter.com/A...
# 6                                                 NaN
# 7   https://www.facebook.com/ArgentinaEnBeloHorizo...
# 8   https://www.facebook.com/ConsuladoArgentinoenB...
# 9             www.facebook.com/ArgentinaEnCadiz  //
# 10  https://www.facebook.com/ArgEnCiudaddeleste/  ...
# 11  https://twitter.com/argenchicago  //  https://...
# 12      wwww.facebook.com/ArgentinaEnCochabamba  //
# 13  https://www.facebook.com/ArgentinaenColonia  //
# 14                                                NaN
# 15  https://www.facebook.com/ArgEnCuritiba/  //  h...
# 16                                                NaN
# ...

# %%
lista_sedes_datos['redes_sociales'] = lista_sedes_datos['redes_sociales'].astype(str).apply(lambda x: x.split(' '))  
lista_sedes_datos['redes_sociales'] = lista_sedes_datos['redes_sociales'].apply(lambda x: [value for value in x if value != "//" and value != ""])
lista_sedes_datos['redes_sociales'] = lista_sedes_datos['redes_sociales'].apply(lambda x: None if 'nan' in x else x)

# %%
lista_sedes_datos['redes_sociales']
# Out:
# 0      [https://twitter.com/ArgPortoAlegre, https://w...
# 1      [https://www.facebook.com/Consulado-de-la-Rep%...
# 2      [https://www.facebook.com/profile.php?id=10001...
# 3                                 [@ArgentinaEnAsuncion]
# 4                                                   None
#                              ...
# 159    [https://twitter.com/ArgentinaEnUru, https://w...
# 160    [https://twitter.com/argenvenezuela?lang=es, h...
# 161    [https://www.facebook.com/ArgentinaEnVietnam/,...
# 162                                                 None
# 163            [https://www.facebook.com/ArgEnPalestina]
# Name: redes_sociales, Length: 164, dtype: object
